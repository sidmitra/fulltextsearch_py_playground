# %% [markdown]
# # Download Dataset

# %% [markdown]
# [Crunchbase](https://data.crunchbase.com/docs/daily-csv-export) makes a CSV export available for developers seeking to access Crunchbase data without coding against the REST API. The export is updated each morning and includes separate files for companies, people, funding rounds, acquisitions, and IPOs. **Enterprise or Applications Access is required to download the CSV files**. The Daily CSV is NOT intended to be a replacement for the full REST API.
#
# The CSV export is a compressed TAR file containing the following files:
#
# - organizations.csv - Organization profiles available on Crunchbase platform
# - organization_descriptions.csv - Long descriptions for organization profiles
# - acquisitions.csv - List of all acquisitions available on Crunchbase platform
# - org_parents.csv - Mapping between parent organizations and subsidaries
# - ipos.csv - Detail for each IPO in the dataset
# - category_groups.csv - Mappings between organization categories and category groups
# - people.csv - People profiles available on Crunchbase platform
# - people_descriptions.csv - Long descriptions for people profiles
# - degrees.csv - Detail for people's education background
# - jobs.csv - List of all job and advisory roles
# - investors.csv - Active investors, including both organizations and people
# - investments.csv - All investments made by investors
# - investment_partners.csv - Partners who are responsible for their firm's investments
# - funds.csv - Details for investors' investment funds
# - funding_rounds.csv - Details for each funding round in the dataset
# - events.csv - Event details
# - event_appearances.csv - Event participation details

# %%
import os
import sys
from termcolor import colored

CRUNCHBASE_USER_KEY = os.getenv("CRUNCHBASE_USER_KEY") # `export CRUNCHBASE_USER_KEY=<key>`
if not CRUNCHBASE_USER_KEY:
    print(colored("*No* Crunchbase user key found in env.", "red"))

# %%
from fastdownload import FastDownload
downloader = FastDownload()
path = downloader.get(f"https://api.crunchbase.com/bulk/v4/bulk_export.tar.gz?user_key={CRUNCHBASE_USER_KEY}")
print("Downloaded and extracted to", path)
for file in path.ls():
    print(file)
# Out:
# Downloaded and extracted to /Users/sidmitra/.fastdownload/data/bulk_export
# /Users/sidmitra/.fastdownload/data/bulk_export/funding_rounds.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/category_groups.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/people_descriptions.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/investors.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/people.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/investment_partners.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/checksum.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/organization_descriptions.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/jobs.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/org_parents.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/event_appearances.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/organizations.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/events.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/funds.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/degrees.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/ipos.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/investments.csv
# /Users/sidmitra/.fastdownload/data/bulk_export/acquisitions.csv
# /Users/sidmitra/Library/Caches/pypoetry/virtualenvs/postgres-fts-VbRma9CQ-py3.11/lib/python3.11/site-packages/fastprogress/fastprogress.py:107: UserWarning: Couldn't import ipywidgets properly, progress bar will use console behavior
#   warn("Couldn't import ipywidgets properly, progress bar will use console behavior")

# %% [markdown]
# # Read organizations dataset

# %%
import pandas as pd
df = pd.read_csv(path / "organizations.csv")
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])
df['founded_on'] = pd.to_datetime(df['founded_on'], format="ISO8601", errors='coerce') # ignore dates out if range pd.Timestamp.min, pd.Timestamp.max!!
df['last_funding_on'] = pd.to_datetime(df['last_funding_on'], format="ISO8601", errors='coerce')
df['closed_on'] = pd.to_datetime(df['closed_on'], format="ISO8601")
df
# Out:
#                                          uuid  \
# 0        e1393508-30ea-8a36-3f96-dd3226033abd
# 1        bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7
# 2        5f2b40b8-d1b3-d323-d81a-b7a8e89553d0
# 3        f4d5ab44-058b-298b-ea81-380e6e9a8eec
# 4        df662812-7f97-0b43-9d3e-12f64f504fbb
# ...                                       ...
# 2940955  1b89aba8-5368-4a27-b2c3-27e6bfb0efe2
# 2940956  4e2d7172-cef1-431a-b31a-3a4ff27f97bc
# 2940957  c649d618-52f4-4ea9-b695-e84cda1b82b2
# 2940958  19df6bf9-1b57-4782-8894-47bcd9cee4eb
# 2940959  216e93f7-696c-4279-b6fe-a0a9164aa49c
#
#                                        name          type  \
# 0                                  Wetpaint  organization
# 1                                      Zoho  organization
# 2                                      Digg  organization
# 3                           Omidyar Network  organization
# 4                                      Meta  organization
# ...                                     ...           ...
# 2940955  WordPress website design Australia  organization
# 2940956                        Pulse Rescue  organization
# 2940957                            AutoPhil  organization
# 2940958                   Quiero un Negocio  organization
# 2940959                             HyprWin  organization
#
#                                   permalink  \
# 0                                  wetpaint
# 1                                      zoho
# 2                                      digg
# 3                           omidyar-network
# 4                                  facebook
# ...                                     ...
# 2940955  wordpress-website-design-australia
# 2940956                        pulse-rescue
# 2940957                            autophil
# 2940958                   quiero-un-negocio
# 2940959                             hyprwin
#
#                                                     cb_url      rank  \
# 0         https://www.crunchbase.com/organization/wetpaint  176371.0
# 1             https://www.crunchbase.com/organization/zoho   11338.0
# 2             https://www.crunchbase.com/organization/digg   20754.0
# 3        https://www.crunchbase.com/organization/omidya...   85066.0
# 4         https://www.crunchbase.com/organization/facebook      59.0
# ...                                                    ...       ...
# 2940955  https://www.crunchbase.com/organization/wordpr...       NaN
# 2940956  https://www.crunchbase.com/organization/pulse-...       NaN
# 2940957   https://www.crunchbase.com/organization/autophil       NaN
# 2940958  https://www.crunchbase.com/organization/quiero...       NaN
# 2940959    https://www.crunchbase.com/organization/hyprwin       NaN
#
#                  created_at          updated_at                  legal_name  \
# 0       2007-05-25 13:51:27 2022-03-07 05:47:35                         NaN
# 1       2007-05-26 02:30:28 2023-06-19 08:30:22  Zoho Corporation Pvt. Ltd.
# 2       2007-05-26 03:03:23 2018-12-10 10:09:14          Digg Holdings, LLC
# 3       2007-05-26 03:21:34 2022-07-19 01:45:23                         NaN
# 4       2007-05-26 04:22:15 2023-05-04 18:27:53        Meta Platforms, Inc.
# ...                     ...                 ...                         ...
# 2940955 2023-07-08 23:18:29 2023-07-08 23:18:29                         NaN
# 2940956 2023-07-08 23:26:06 2023-07-08 23:26:06            Pulse Rescue LLC
# 2940957 2023-07-08 23:26:42 2023-07-08 23:32:28                AutoPhil Inc
# 2940958 2023-07-08 23:45:35 2023-07-08 23:45:35           Quiero un Negocio
# 2940959 2023-07-09 00:04:31 2023-07-09 00:04:31                HyprWin Inc.
#
#                     roles  ...           phone  \
# 0                 company  ...    206-859-6300
# 1        investor,company  ...  044 - 67447070
# 2                 company  ...    877-342-7222
# 3        investor,company  ...    650.482.2500
# 4        investor,company  ...             NaN
# ...                   ...  ...             ...
# 2940955           company  ...             NaN
# 2940956           company  ...             NaN
# 2940957           company  ...      3047109929
# 2940958           company  ...             NaN
# 2940959           company  ...             NaN
#
#                                    facebook_url  \
# 0             https://www.facebook.com/Wetpaint
# 1                  http://www.facebook.com/zoho
# 2                  http://www.facebook.com/digg
# 3        http://www.facebook.com/OmidyarNetwork
# 4                 https://www.facebook.com/Meta
# ...                                         ...
# 2940955                                     NaN
# 2940956                                     NaN
# 2940957                                     NaN
# 2940958                                     NaN
# 2940959                                     NaN
#
#                                            linkedin_url  \
# 0                                                   NaN
# 1                 https://www.linkedin.com/company/zoho
# 2                  http://www.linkedin.com/company/digg
# 3                 http://www.linkedin.com/company/22806
# 4                 https://www.linkedin.com/company/meta
# ...                                                 ...
# 2940955                                             NaN
# 2940956  https://www.linkedin.com/company/pulse-rescue/
# 2940957   https://www.linkedin.com/company/autophil-us/
# 2940958                                             NaN
# 2940959        https://www.linkedin.com/company/hyprwin
#
#                                 twitter_url  \
# 0            https://twitter.com/wetpainttv
# 1                   http://twitter.com/zoho
# 2                   http://twitter.com/digg
# 3         http://twitter.com/OmidyarNetwork
# 4              https://www.twitter.com/Meta
# ...                                     ...
# 2940955                                 NaN
# 2940956                                 NaN
# 2940957                                 NaN
# 2940958  https://twitter.com/Quiero1Negocio
# 2940959                                 NaN
#
#                                                   logo_url    alias1  \
# 0        https://res.cloudinary.com/crunchbase-producti...       NaN
# 1        https://res.cloudinary.com/crunchbase-producti...       NaN
# 2        https://res.cloudinary.com/crunchbase-producti...       NaN
# 3        https://res.cloudinary.com/crunchbase-producti...       NaN
# 4        https://res.cloudinary.com/crunchbase-producti...  Facebook
# ...                                                    ...       ...
# 2940955                                                NaN       NaN
# 2940956  https://res.cloudinary.com/crunchbase-producti...       NaN
# 2940957  https://res.cloudinary.com/crunchbase-producti...       NaN
# 2940958  https://res.cloudinary.com/crunchbase-producti...       NaN
# 2940959  https://res.cloudinary.com/crunchbase-producti...       NaN
#
#                  alias2 alias3 primary_role num_exits
# 0                   NaN    NaN      company       NaN
# 1                   NaN    NaN      company       2.0
# 2                   NaN    NaN      company       NaN
# 3                   NaN    NaN     investor      56.0
# 4        Facebook, Inc.    NaN      company       1.0
# ...                 ...    ...          ...       ...
# 2940955             NaN    NaN      company       NaN
# 2940956             NaN    NaN      company       NaN
# 2940957             NaN    NaN      company       NaN
# 2940958             NaN    NaN      company       NaN
# 2940959             NaN    NaN      company       NaN
#
# [2940960 rows x 41 columns]

# %%
df.dtypes
# Out:
# uuid                                   object
# name                                   object
# type                                   object
# permalink                              object
# cb_url                                 object
# rank                                  float64
# created_at                     datetime64[ns]
# updated_at                     datetime64[ns]
# legal_name                             object
# roles                                  object
# domain                                 object
# homepage_url                           object
# country_code                           object
# state_code                             object
# region                                 object
# city                                   object
# address                                object
# postal_code                            object
# status                                 object
# short_description                      object
# category_list                          object
# category_groups_list                   object
# num_funding_rounds                    float64
# total_funding_usd                     float64
# total_funding                         float64
# total_funding_currency_code            object
# founded_on                     datetime64[ns]
# last_funding_on                datetime64[ns]
# closed_on                      datetime64[ns]
# employee_count                         object
# email                                  object
# phone                                  object
# facebook_url                           object
# linkedin_url                           object
# twitter_url                            object
# logo_url                               object
# alias1                                 object
# alias2                                 object
# alias3                                 object
# primary_role                           object
# num_exits                             float64
# dtype: object

# %% [markdown]
# # Ensure Postgres connection

# %%
import psycopg

DATABASE_URL = "postgres://localhost:5432"
connection = psycopg.connect(DATABASE_URL)        
connection.autocommit = True # Just to bypass transaction stuff in this notebook. Not good practice otherwise.
cursor = connection.cursor()
cursor.execute("SELECT VERSION()")
print(cursor.fetchone())
cursor.close()
# Out:
# ('PostgreSQL 15.3 on aarch64-apple-darwin21.6.0, compiled by Apple clang version 14.0.0 (clang-1400.0.29.102), 64-bit',)

# %% [markdown]
# # Create new Postgres database

# %%
cursor = connection.cursor()
cursor.execute("DROP DATABASE IF EXISTS fts_crunchbase")
cursor.execute("CREATE DATABASE fts_crunchbase")
cursor.close()
connection.close()

# %% [markdown]
# Reconnect to the new database.

# %%
DATABASE_URL_FTS = DATABASE_URL + "/fts_crunchbase"
connection = psycopg.connect(DATABASE_URL_FTS)
cursor = connection.cursor()

# %%
df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %% [markdown]
# ## Create new table

# %%
cursor.execute("""CREATE TABLE organizations (
    uuid uuid,
    name text,
    type text,
    permalink text,
    cb_url text,
    rank int,
    created_at timestamp,
    updated_at timestamp,
    legal_name text,
    roles text,
    domain text,
    homepage_url text,
    country_code text,
    state_code text,
    region text,
    city text,
    address text,
    postal_code text,
    status text,
    short_description text,
    category_list text,
    category_groups_list text,
    num_funding_rounds int,
    total_funding_usd int,
    total_funding int,
    total_funding_currency_code text,
    founded_on timestamp,
    last_funding_on timestamp,
    closed_on timestamp,
    employee_count int,
    email text,
    phone text,
    facebook_url text,
    linked_url text,
    twitter_url text,
    logo_url text,
    alias1 text,
    alias2 text,
    alias3 text,
    primary_role text,
    num_exits int
)
""")
# Out:
# <psycopg.Cursor [COMMAND_OK] [INTRANS] (host=localhost user=sidmitra database=fts_crunchbase) at 0x225c231c0>

# %%
# Create a list of tupples from the dataframe values
tuples = [tuple(x) for x in df.to_numpy()]
# Comma-separated dataframe columns
cols = ','.join(list(df.columns))

# %%
# Insert to table
substr = ",".join(["%s"]*len(df.columns))
print(substr, len(substr), len(df.columns))
print(cols)
query  = f"INSERT INTO organizations VALUES({substr})"# % (cols)
print(query)
cursor.executemany(query, tuples)
# Out:
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s 122 41
# uuid,name,type,permalink,cb_url,rank,created_at,updated_at,legal_name,roles,domain,homepage_url,country_code,state_code,region,city,address,postal_code,status,short_description,category_list,category_groups_list,num_funding_rounds,total_funding_usd,total_funding,total_funding_currency_code,founded_on,last_funding_on,closed_on,employee_count,email,phone,facebook_url,linkedin_url,twitter_url,logo_url,alias1,alias2,alias3,primary_role,num_exits
# INSERT INTO organizations VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# Cell In[11], line 7
#       5 query  = f"INSERT INTO organizations VALUES({substr})"# % (cols)
#       6 print(query)
# ----> 7 cursor.executemany(query, tuples)
#
# File ~/Library/Caches/pypoetry/virtualenvs/postgres-fts-VbRma9CQ-py3.11/lib/python3.11/site-packages/psycopg/cursor.py:758, in Cursor.executemany(self, query, params_seq, returning)
#     754             self._conn.wait(
#     755                 self._executemany_gen_no_pipeline(query, params_seq, returning)
#     756             )
#     757 except e._NO_TRACEBACK as ex:
# --> 758     raise ex.with_traceback(None)
#
# InvalidTextRepresentation: invalid input syntax for type integer: "51-100"
# CONTEXT:  unnamed portal parameter $30 = '...'

# %%
﻿﻿df['col1_converted'] = pd.to_datetime(df['col1'])
# Out:
#   Cell In[1], line 1
#     ﻿﻿df['col1_converted'] = pd.to_datetime(df['col1'])
#     ^
# SyntaxError: invalid non-printable character U+FEFF
